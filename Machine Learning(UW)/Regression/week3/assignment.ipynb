# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
def polynomial_dframe(feature, degree):
    # assume that degree >= 1
    # initialize the SFrame:
    poly_dframe = pd.DataFrame(data = feature.values, columns= ["power_1"])
    # and set poly_sframe['power_1'] equal to the passed feature
    ...
    # first check if degree > 1
    if degree > 1:
        # then loop over the remaining degrees:
        for power in range(2, degree+1):
            # first we'll give the column a name:
            name = 'power_' + str(power)
            # assign poly_sframe[name] to be feature^power
            poly_dframe[name] = poly_dframe["power_1"] ** power
    return poly_dframe

# %%
dtype_dict = {'bathrooms':float, 'waterfront':int, 'sqft_above':int, 'sqft_living15':float, 'grade':int, 'yr_renovated':int, 'price':float, 'bedrooms':float, 'zipcode':str, 'long':float, 'sqft_lot15':float, 'sqft_living':float, 'floors':str, 'condition':int, 'lat':float, 'date':str, 'sqft_basement':int, 'yr_built':int, 'id':str, 'sqft_lot':int, 'view':int}
sales = pd.read_csv('kc_house_data.csv', dtype=dtype_dict)
sales = sales.sort_values(['sqft_living','price'])

# %%
def plot_power(power):
    poly_data = polynomial_dframe(sales['sqft_living'], power)
    model = LinearRegression()
    model.fit(poly_data,sales['price'])
    print(model.coef_, model.intercept_)
    plt.plot(poly_data[['power_1']],sales['price'],'.',
    poly_data[['power_1']], model.predict(poly_data),'-')
    return model

# %%
plot_power(1)
# Out:
# [280.6235679] -43580.743094474194
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
plot_power(2)
# Out:
# [6.79940947e+01 3.85812609e-02] 199222.2793054845
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
plot_power(3)
# Out:
# [-9.01819864e+01  8.70465089e-02 -3.84055260e-06] 336819.7482198205
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model15 = plot_power(15)
# Out:
# [ 4.56404164e-91 -6.23779015e-50  2.78845913e-56 -2.48920611e-60
#   1.19863929e-74  2.68575522e-71  2.26147568e-67  1.85900299e-63
#   1.47144115e-59  1.09771012e-55  7.43509038e-52  4.23015577e-48
#   1.61618577e-44 -2.49283826e-48  9.59718336e-53] 537116.3296378911

# %%
wk3_kc_house_set_1_data = pd.read_csv("wk3_kc_house_set_1_data.csv",dtype = dtype_dict)
wk3_kc_house_set_2_data = pd.read_csv("wk3_kc_house_set_2_data.csv",dtype = dtype_dict)
wk3_kc_house_set_3_data = pd.read_csv("wk3_kc_house_set_3_data.csv",dtype = dtype_dict)
wk3_kc_house_set_4_data = pd.read_csv("wk3_kc_house_set_4_data.csv",dtype = dtype_dict)

# %%
def plot_power_validation(df,power):
    poly_data = polynomial_dframe(df['sqft_living'], power)
    model = LinearRegression()
    model.fit(poly_data,df['price'])
    print(model.coef_, model.intercept_)
    plt.plot(poly_data[['power_1']],df['price'],'.',
    poly_data[['power_1']], model.predict(poly_data),'-')
    return model

# %%
plot_power_validation(wk3_kc_house_set_1_data,15)
# Out:
# [ 3.05794168e-90  2.21229706e-49  8.63658615e-55  9.95682444e-60
#   3.23082736e-74  1.10358333e-70  8.37724029e-67  6.23411957e-63
#   4.49156442e-59  3.06938763e-55  1.91749300e-51  1.01335180e-47
#   3.62176959e-44 -5.63501661e-48  2.18641116e-52] 539058.8186675454
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
plot_power_validation(wk3_kc_house_set_2_data,15)
# Out:
# [ 2.68007766e-77 -1.28313528e-39 -1.45840576e-44  8.22726892e-50
#  -1.04404871e-53  1.35479893e-58  3.62867884e-55  1.49807489e-51
#   5.73974461e-48  1.95158341e-44  5.37897065e-41  9.38035579e-38
#  -3.62478330e-41  4.63968383e-45 -1.96500572e-49] 506812.10893582343
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
plot_power_validation(wk3_kc_house_set_3_data,15)
# Out:
# [ 2.83751934e-88 -3.80811673e-49 -8.52600668e-55  7.96545956e-59
#   1.57170169e-72  4.27894908e-69  2.68009626e-65  1.63911362e-61
#   9.66435015e-58  5.38044653e-54  2.72563636e-50  1.16253248e-46
#   3.33756141e-43 -6.76238818e-47  3.43132932e-51] 530874.3166533483
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
plot_power_validation(wk3_kc_house_set_4_data,15)
# Out:
# [ 1.37062035e-76 -7.34929941e-40 -2.99040284e-44 -3.69675888e-49
#  -4.17619486e-53  1.30559251e-54  1.27051326e-54  4.87799084e-51
#   1.73524691e-47  5.46982653e-44  1.39568452e-40  2.25011155e-37
#  -9.43820708e-41  1.31553951e-44 -6.09073061e-49] 494822.42730399943
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# ## Quiz Question: Is the sign (positive or negative) for power_15 the same in all four models?

# %% [markdown]
# ## Quiz Question: True/False the plotted fitted lines look the same in all four plots

# %%
wk3_kc_house_valid_data = pd.read_csv("wk3_kc_house_valid_data.csv",dtype = dtype_dict)
wk3_kc_house_train_data = pd.read_csv("wk3_kc_house_train_data.csv",dtype = dtype_dict)
wk3_kc_house_test_data = pd.read_csv("wk3_kc_house_test_data.csv",dtype = dtype_dict)

# %%
def rss(y_true,y_pred):
    return np.sum(np.square(y_true - y_pred))

# %%
def cross_validation(power):
    poly_data = polynomial_dframe(wk3_kc_house_train_data['sqft_living'], power)
    model = LinearRegression()
    model.fit(poly_data,wk3_kc_house_train_data['price'])    
    valid_poly_data = polynomial_dframe(wk3_kc_house_valid_data['sqft_living'], power)
    rss_v = rss(wk3_kc_house_valid_data['price'],model.predict(valid_poly_data))
    #print("rss: {}".format(rss(wk3_kc_house_valid_data['price'],model.predict(valid_poly_data))))    
    return [rss_v,model]

# %%
table = {}
for power in range(1,16):
    table[power] = cross_validation(power)

# %%
sorted_table = sorted(table.items(),key = lambda x:x[1][0])

# %%
power,[rss_v,model] = sorted_table[0]

# %%
power,rss_v
# Out:
# (6, 566268533238196.2)

# %%
poly_data = polynomial_dframe(wk3_kc_house_test_data['sqft_living'], power)
rss(model.predict(poly_data),wk3_kc_house_test_data['price'])
# Out:
# 135225107290003.81
